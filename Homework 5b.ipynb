# %% [markdown]
# # Homework 5 STAT 411
# # Ashley Snell

# %%
import pandas as pa
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import numpy.linalg as la

# %%
# I had to use a new data set because my original one was giving me tons of trouble with PCA Analysis

# %%
aba = pa.read_csv('Data Sets/Abalone/abalone.csv', names = ['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 
                      'Sucked_weight', 'Viscera_weight', 'Shell_weight',
                                          'Rings'])
aba.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Sucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140         0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255         0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770         0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160         0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050         0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
list(aba.dtypes)
# Out:
# [dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64')]

# %%
aba.shape
# About 4,000 samples, 9 features
# Out:
# (4177, 9)

# %%
# Build a matrix of the predictors and results

X = np.array(aba.iloc[:, 1:-1])
y = np.array(aba.iloc[:, -1])

# %%
plt.scatter(X[:, 1], X[:, 2], c=y, marker='.')

# %%
# We can check how the predictors do at estimating using Rings (9), Height (4), and Whole Weight (5)
plt.plot(X[y<6, 0], X[y<6, 1], 'r.')
plt.plot(X[y>=6, 0], X[y>=6, 1], 'g.')

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=7) # Use PCA to identify the two most important components; Component here means a linear combination of the features

Xpca = pca.fit_transform(X);

# %%
plt.scatter(Xpca[:, 0], Xpca[:, 1], c=y, marker='.')

# %%
pca.explained_variance_
# Out:
# array([3.38170727e-01, 3.96403025e-03, 2.90771416e-03, 1.05490434e-03,
#        4.89663867e-04, 4.26787482e-04, 1.48141736e-04])

# %%
sum(pca.explained_variance_)
# Out:
# 0.3471619683501868
